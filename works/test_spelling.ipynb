# %%
import pandas as pd

# %%
total = pd.read_csv('./total_40.csv')
total['title'] = total['title'].astype(str)
total.tail(5)
# Out:
#                   info        date  rating  \
# 48804        하드웨어 엔지니어  2020.07.31     1.0
# 48805        연구개발(R&D)  2020.07.31     4.0
# 48806       마케팅·홍보 전문가  2020.07.31     4.0
# 48807  경영전략·사업기획·분석전문가  2020.07.31     4.0
# 48808        연구개발(R&D)  2020.07.31     4.0
#
#                                           title   name
# 48804          “연구개발 위주의 sw회사로 변해가고있는 자동차 부품사.”  현대모비스
# 48805                                    “무난무난”  현대모비스
# 48806  “현대기아차 의존도로 안정적이지만, 미래 원동력 발굴에 힘들어하는 회사”  현대모비스
# 48807                  “높은 상여금, 역삼역에서 회사 생활 가능”  현대모비스
# 48808               “괜찮은 연봉, 글로벌 기업과의 비즈니스 기회.”  현대모비스

# %%
top = pd.read_csv('./top_10.csv')
top['title'] = top['title'].astype(str)
top.tail(5)
# Out:
#               info        date  rating  \
# 34392    연구개발(R&D)  2020.07.31     4.0
# 34393      IT 엔지니어  2020.07.31     5.0
# 34394  생산엔지니어·생산관리  2020.07.31     4.0
# 34395  품질관리·보증 전문가  2020.07.31     4.0
# 34396    연구개발(R&D)  2020.07.31     4.0
#
#                                                    title   name  \
# 34392                        동종 자동차 업계 기업들보다는 안정적인 느낌입니다  현대자동차
# 34393                                            만족스럽습니다  현대자동차
# 34394  글로벌 기업으로 보이고 싶은 회사 밖에서 바라보았을 땐 엄청 좋은 회사이나 실제 근...  현대자동차
# 34395                  불합리한 점이 없진 않지만 복지  연봉이 좋아 다닐만한 회사  현대자동차
# 34396  자동차 산업 환경 변화에 발맞추어 새로운 산업 패러다임으로의 전환을 준비하고 있지만...  현대자동차
#
#                                                    spell
# 34392                        동종 자동차 업계 기업들보다는 안정적인 느낌입니다
# 34393                                            만족스럽습니다
# 34394  글로벌 기업으로 보이고 싶은 회사 밖에서 바라보았을 땐 엄청 좋은 회사이나 실제 근...
# 34395                  불합리한 점이 없진 않지만 복지  연봉이 좋아 다닐만한 회사
# ...

# %%
# total, top 기본 전처리
# 따옴표 / # , / . / 특정 단어 
total['title'] = total['title'].apply(lambda x: x.replace('“', ''))
total['title'] = total['title'].apply(lambda x: x.replace('”', ''))
total['title'] = total['title'].apply(lambda x: x.replace('\'', ''))
total['title'] = total['title'].apply(lambda x: x.replace(',', ''))
total['title'] = total['title'].apply(lambda x: x.replace('.', ''))
total['title'] = total['title'].apply(lambda x: x.replace("/", ''))

total['title'] = total['title'].apply(lambda x: x.replace('비젼', '비전'))
total['title'] = total['title'].apply(lambda x: x.replace('그냥저냥', '그저 그런'))
total['title'] = total['title'].apply(lambda x: x.replace('걍', '그냥'))
total['title'] = total['title'].apply(lambda x: x.replace('캐이비', 'KB'))
total['title'] = total['title'].apply(lambda x: x.replace('It', 'IT'))

total['title'] = total['title'].apply(lambda x: x.replace('부바부', '부서 간 차이 있음'))
total['title'] = total['title'].apply(lambda x: x.replace('개바개', '개인 간 차이 있음'))
total['title'] = total['title'].apply(lambda x: x.replace('팀바팀', '팀별 차이 있음'))
total['title'] = total['title'].apply(lambda x: x.replace('케바케', '상황마다 다름'))
total['title'] = total['title'].apply(lambda x: x.replace('캐바캐', '상황마다 다름'))
total['title'] = total['title'].apply(lambda x: x.replace('사바사', '사람마다 다름'))

total['title'] = total['title'].apply(lambda x: x.replace('빵빵', '넉넉함'))
total['title'] = total['title'].apply(lambda x: x.replace('so so', '보통'))
total['title'] = total['title'].apply(lambda x: x.replace('soso', '보통'))
total['title'] = total['title'].apply(lambda x: x.replace('쏘쏘', '보통'))
total['title'] = total['title'].apply(lambda x: x.replace('쏘소', '보통'))
total['title'] = total['title'].apply(lambda x: x.replace('소쏘', '보통'))

total['title'] = total['title'].apply(lambda x: x.replace('고인 물', '고인물'))
total['title'] = total['title'].apply(lambda x: x.replace('워러벨', '워라밸'))
total['title'] = total['title'].apply(lambda x: x.replace('워라벨', '워라밸'))
total['title'] = total['title'].apply(lambda x: x.replace('워라맬', '워라밸'))
total['title'] = total['title'].apply(lambda x: x.replace('워라멜', '워라밸'))
total['title'] = total['title'].apply(lambda x: x.replace('워리벨', '워라밸'))
total['title'] = total['title'].apply(lambda x: x.replace('워리밸', '워라밸'))
total['title'] = total['title'].apply(lambda x: x.replace('와 라벨', '워라밸'))
total['title'] = total['title'].apply(lambda x: x.replace('와 라밸', '워라밸'))


top['title'] = top['title'].apply(lambda x: x.replace('“', ''))
top['title'] = top['title'].apply(lambda x: x.replace('”', ''))
top['title'] = top['title'].apply(lambda x: x.replace('\'', ''))
top['title'] = top['title'].apply(lambda x: x.replace(',', ''))
top['title'] = top['title'].apply(lambda x: x.replace('.', ''))
top['title'] = top['title'].apply(lambda x: x.replace("/", ''))

top['title'] = top['title'].apply(lambda x: x.replace('비젼', '비전'))
top['title'] = top['title'].apply(lambda x: x.replace('그냥저냥', '그저 그런'))
top['title'] = top['title'].apply(lambda x: x.replace('걍', '그냥'))
top['title'] = top['title'].apply(lambda x: x.replace('캐이비', 'KB'))
top['title'] = top['title'].apply(lambda x: x.replace('It', 'IT'))

top['title'] = top['title'].apply(lambda x: x.replace('부바부', '부서 간 차이 있음'))
top['title'] = top['title'].apply(lambda x: x.replace('개바개', '개인 간 차이 있음'))
top['title'] = top['title'].apply(lambda x: x.replace('팀바팀', '팀별 차이 있음'))
top['title'] = top['title'].apply(lambda x: x.replace('케바케', '상황마다 다름'))
top['title'] = top['title'].apply(lambda x: x.replace('캐바캐', '상황마다 다름'))
top['title'] = top['title'].apply(lambda x: x.replace('사바사', '사람마다 다름'))

top['title'] = top['title'].apply(lambda x: x.replace('빵빵', '넉넉함'))
top['title'] = top['title'].apply(lambda x: x.replace('so so', '보통'))
top['title'] = top['title'].apply(lambda x: x.replace('soso', '보통'))
top['title'] = top['title'].apply(lambda x: x.replace('쏘쏘', '보통'))
top['title'] = top['title'].apply(lambda x: x.replace('쏘소', '보통'))
top['title'] = top['title'].apply(lambda x: x.replace('소쏘', '보통'))

top['title'] = top['title'].apply(lambda x: x.replace('고인 물', '고인물'))
top['title'] = top['title'].apply(lambda x: x.replace('워러벨', '워라밸'))
top['title'] = top['title'].apply(lambda x: x.replace('워라벨', '워라밸'))
top['title'] = top['title'].apply(lambda x: x.replace('워라맬', '워라밸'))
top['title'] = top['title'].apply(lambda x: x.replace('워라멜', '워라밸'))
top['title'] = top['title'].apply(lambda x: x.replace('워리벨', '워라밸'))
top['title'] = top['title'].apply(lambda x: x.replace('워리밸', '워라밸'))
top['title'] = top['title'].apply(lambda x: x.replace('와 라벨', '워라밸'))
top['title'] = top['title'].apply(lambda x: x.replace('와 라밸', '워라밸'))

# %%
total.head(10)
# Out:
#             info        date  rating                   title     name
# 0     조선·해양 엔지니어  2023.11.27     1.0             최악의 기업문화 회사  HD현대중공업
# 1     조선·해양 엔지니어  2023.11.26     3.0              아직은 잘 모르겠다  HD현대중공업
# 2    경영지원·관리 전문가  2023.11.26     3.0      사회초년생이 경험 쌓기 좋은 회사  HD현대중공업
# 3      연구개발(R&D)  2023.11.25     2.0  왜 사람들이 오지말라고 하는지 이해가 됨  HD현대중공업
# 4    생산엔지니어·생산관리  2023.11.25     2.0              야근이 당연한 회사  HD현대중공업
# 5     조선·해양 엔지니어  2023.11.24     2.0                관료주의 끝판왕  HD현대중공업
# 6     조선·해양 엔지니어  2023.11.24     3.0            워라밸이 보장되는 회사  HD현대중공업
# 7  구매·물류·SCM 전문가  2023.11.23     3.0              그냥 HD현대 그룹  HD현대중공업
# 8     조선·해양 엔지니어  2023.11.21     3.0                공무원같은 회사  HD현대중공업
# 9      연구개발(R&D)  2023.11.20     5.0              워라밸이보장되는회사  HD현대중공업

# %%
total.tail(10)
# Out:
#                   info        date  rating  \
# 48799        연구개발(R&D)  2020.08.08     4.0
# 48800          IT 엔지니어  2020.08.08     4.0
# 48801      품질관리·보증 전문가  2020.08.07     5.0
# 48802        연구개발(R&D)  2020.08.07     4.0
# 48803    구매·물류·SCM 전문가  2020.08.07     4.0
# 48804        하드웨어 엔지니어  2020.07.31     1.0
# 48805        연구개발(R&D)  2020.07.31     4.0
# 48806       마케팅·홍보 전문가  2020.07.31     4.0
# 48807  경영전략·사업기획·분석전문가  2020.07.31     4.0
# 48808        연구개발(R&D)  2020.07.31     4.0
#
#                                        title   name
# 48799                      이만한 워라밸이 있을까싶은 회사  현대모비스
# 48800                  안정적이고 커리어를 쌓을 수 있는 회사  현대모비스
# 48801                           이제부터가 중요한 회사  현대모비스
# 48802                           워라밸이 보장되는 회사  현대모비스
# 48803                          사기업계의 공무원 끝판왕  현대모비스
# 48804          연구개발 위주의 sw회사로 변해가고있는 자동차 부품사  현대모비스
# 48805                                   무난무난  현대모비스
# 48806  현대기아차 의존도로 안정적이지만 미래 원동력 발굴에 힘들어하는 회사  현대모비스
# ...

# %%
top.head(10)
# Out:
#            info        date  rating                        title   name  \
# 0    마케팅·홍보 전문가  2023.11.07     2.0               내가 발전할 수 없는 회사  cjENM
# 1  상품기획·MD·디자이너  2023.11.15     5.0                       괜찮은 회사  cjENM
# 2    마케팅·홍보 전문가  2023.11.10     3.0                  오래 있기 어려운 곳  cjENM
# 3       IT 엔지니어  2023.11.06     2.0                      위태로운 회사  cjENM
# 4  상품기획·MD·디자이너  2023.11.03     2.0     적당한 급여 그리고 적당히 다니기 괜찮은 곳  cjENM
# 5  상품기획·MD·디자이너  2023.11.03     3.0          복지가 좋다  복지가 좋다  복지가  cjENM
# 6  상품기획·MD·디자이너  2023.11.03     4.0                    복지가 좋은 회사  cjENM
# 7  상품기획·MD·디자이너  2023.11.03     3.0  하기에 따라 좋을 수도 안 좋을 수도 있는 회사   cjENM
# 8       IT 엔지니어  2023.11.02     3.0                 워라밸이 보장되는 회사  cjENM
# 9   경영지원·관리 전문가  2023.11.01     2.0             안주하고 싶으면 남아있을 회사  cjENM
#
#                          spell
# 0               내가 발전할 수 없는 회사
# 1                       괜찮은 회사
# 2                  오래 있기 어려운 곳
# 3                      위태로운 회사
# ...

# %%
top.tail(10)
# Out:
#               info        date  rating  \
# 34387    연구개발(R&D)  2020.08.07     4.0
# 34388    연구개발(R&D)  2020.08.07     4.0
# 34389    연구개발(R&D)  2020.08.07     4.0
# 34390  생산엔지니어·생산관리  2020.08.07     4.0
# 34391    고객서비스 전문가  2020.07.31     4.0
# 34392    연구개발(R&D)  2020.07.31     4.0
# 34393      IT 엔지니어  2020.07.31     5.0
# 34394  생산엔지니어·생산관리  2020.07.31     4.0
# 34395  품질관리·보증 전문가  2020.07.31     4.0
# 34396    연구개발(R&D)  2020.07.31     4.0
#
#                                                    title   name  \
# 34387                                     차 좋아하는 사람한텐 최고  현대자동차
# 34388                                            안정적인 회사  현대자동차
# 34389                                           공 같은 사기업  현대자동차
# 34390                                         무난하고 좋은 회사  현대자동차
# 34391                              다닐만한 회사  남들이 부러워하는 회사  현대자동차
# 34392                        동종 자동차 업계 기업들보다는 안정적인 느낌입니다  현대자동차
# 34393                                            만족스럽습니다  현대자동차
# ...

# %%
# !pip uninstall -y py-hanspell hanspell
# !pip install py-hanspell
# Out:
# WARNING: Skipping py-hanspell as it is not installed.
# WARNING: Skipping hanspell as it is not installed.
# ...
#   Using cached py-hanspell-1.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\kmk45\AppData\Local\Temp\pip-install-p7qos6lt\py-hanspell_60a305a7fe2d432b889de24254470237\setup.py", line 2, in <module>
#           from pip.req import parse_requirements
#       ModuleNotFoundError: No module named 'pip.req'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# ...

# %%
from hanspell import spell_checker
# payload = {
#         'passportKey':'7abd8c2de275d4dda479825c19ded0bffe28f3fe',
#         '_callback': 'jQuery11240003383472025177525_1680133565087',
#         'q': text,
#         'where': 'nexearch',
#         'color_blindness': 0
#     }

#     headers = {
#         'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
#         'referer': 'https://search.naver.com/',
#     }
text = "아버지가방에들어가신다나는오늘코딩을했다"
spell_checker.check(text).as_dict()['checked']
# Out:
# '아버지가 방에 들어가신다 나는 오늘 코딩을 했다'

# %%
spell_lst = []
for text in total['title']:
    try:
        spell_checked = spell_checker.check(text).as_dict()['checked']
    except:
        spell_checked = None
    spell_lst.append(spell_checked)

# %%
top_spell_lst = []
for text in top['title']:
    try:
        spell_checked = spell_checker.check(text).as_dict()['checked']
    except:
        spell_checked = None
    top_spell_lst.append(spell_checked)

# %%
total['spell'] = spell_lst

# %%
total

# %%
top['spell'] =top_spell_lst

# %%
top.to_csv('total_40_spell.csv', encoding='utf-8', index=False)

# %%
top.to_csv('top_10.csv', encoding='utf-8', index=False)
